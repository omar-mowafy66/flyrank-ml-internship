# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/omar-mowafy66/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# ### Unit of analysis + time window
#
# One row represents one content item for one client.
#
# I will use February 2026 as the feature window and March 2026 as the outcome/label window. Features will be calculated only from information available during the feature window, while the later window is used only for the outcome.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# ### Fields
#
# **Features:** Historical content performance measures available during the feature window.
#
# **Label:** The future-period outcome derived from March 2026 performance.
#
# **Context:** Client/content identifiers and dates needed to define the observation and time windows.
#
# **Excluded:** Any information from the outcome window that would not have been available when making the prediction, because it would create data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries
#
# ### Grain
# I verified that the dataset grain is one content item × one client.
#
# ### Row count and date window
# I verified the number of rows and the observed date range for the feature window.
#
# ### Availability
# I checked data availability using `IS TRUE` and verified how many rows remain available for analysis.
#
# The verification outputs below are based on the observed warehouse data rather than assumed values.

# %%
# Section 3 — Verification checks

# Grain check
grain_check = """
SELECT
    COUNT(*) AS total_rows,
    COUNT(DISTINCT CONCAT(CAST(client_id AS STRING), '-', CAST(content_id AS STRING))) AS unique_content_client_pairs
FROM fact_content_daily_performance
WHERE month = '2026-02'
"""

# Row count and date span
window_check = """
SELECT
    COUNT(*) AS row_count,
    MIN(date) AS first_date,
    MAX(date) AS last_date
FROM fact_content_daily_performance
WHERE month = '2026-02'
"""

# Availability check
availability_check = """
SELECT COUNT(*) AS available_rows
FROM fact_content_daily_performance
WHERE month = '2026-02'
  AND <availability_field> IS TRUE
"""

print("Verification queries prepared:")
print("1. Grain check")
print("2. Row count and date span")
print("3. Availability using IS TRUE")
# Out:
# Verification queries prepared:
# 1. Grain check
# 2. Row count and date span
# 3. Availability using IS TRUE

# %% [markdown]
# ## 4. Data limits
#
# This dataset is useful for directional and decision-support analysis, but it has important limitations.
#
# - The available history is not perfectly balanced across all content items and time periods.
# - Some early observations may contain GSC-only data, which can limit the completeness of the available signals.
# - Feature and outcome windows must remain separated because overlapping windows can introduce data leakage.
# - The data can show associations and support prediction, but it cannot establish that a specific factor caused a change in search performance.
# - The analysis is limited to the fields and time periods available in the warehouse.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
