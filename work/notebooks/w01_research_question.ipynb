# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/omar-mowafy66/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose Lane 2 — Refresh / Content Opportunity Scoring because I want to identify which pages should be reviewed first for refresh or content improvement. This lane is useful because the starter data contains observable signals such as impressions, position, CTR, content age, and engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
# Decision: Which pages should be reviewed first for refresh or content improvement?
# Action: A content team can review the highest-ranked pages and decide whether to refresh, improve, protect, or monitor them.
# Cost of a wrong call: A wrong recommendation can waste the team's limited review time, while missing a good page can leave an important opportunity unreviewed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import os
import sys
import subprocess

REPO_URL = "https://github.com/omar-mowafy66/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print(os.getcwd())
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 pages. About 54.2% of the pages are labeled as declining, and the median number of impressions is 731. This suggests that the dataset contains a meaningful number of pages with measurable search visibility, making refresh and content opportunity scoring worth investigating.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Declining rate:", round(
    df["trend_direction"].str.lower().eq("down").mean(), 3
))
print("Median impressions:", df["impressions_90d"].median())
# Out:
# Number of pages: 30000
# Declining rate: 0.542
# Median impressions: 731.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project can identify observed patterns and rank pages for review based on measurable signals. It can provide directional, decision-support recommendations. It cannot prove that refreshing a page will cause a page to recover, and it cannot prove or predict Google's ranking algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
