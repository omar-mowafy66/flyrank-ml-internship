# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/omar-mowafy66/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# My lane: Refresh / Content Opportunity Scoring.
# Task type: Ranking / Scoring. The goal is to rank content pages by how strongly they should be reviewed for refresh or improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Target/proxy: is_declining_label. This is a proxy label based on the current trend_direction field. It is a rule-based proxy rather than a future observed outcome. A stronger future version could predict decline using a future time window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Success metric: Precision@50.
# This metric measures how many of the top 50 recommended pages are actually positive according to the chosen proxy. It matches the real decision because a reviewer can only review a limited number of pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# Unit of analysis: One row represents one content page.
# Each page has observable signals such as impressions, sessions, content age, and trend information. The dataframe below shows these page-level observations.

# %%
import pandas as pd
# Load the starter dataset directly from GitHub
url = "https://raw.githubusercontent.com/omar-mowafy66/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

# Show the unit of analysis
sample = df[
    [
        "content_id",
        "client_id",
        "impressions_90d",
        "sessions_90d",
        "content_age_days",
        "trend_direction"
    ]
].head(10)

print("One row = one content page")
display(sample)
# Out:
# One row = one content page
#              content_id          client_id  impressions_90d  sessions_90d  \
# 0  content_304f48230142  client_f369cb89fc             3803            17
# 1  content_a1fb4e703a9e  client_4e07408562            15320             9
# 2  content_9aa793d4d895  client_7f2253d7e2            12581            11
# 3  content_331d6c4de07b  client_19581e27de            11751            78
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140           145
# 5  content_d4084a4bc775  client_f369cb89fc             3970             5
# 6  content_9a34b442b552  client_8722616204               20             1
# 7  content_a63219c6e95a  client_19581e27de             1724            28
# 8  content_5e6c160719bc  client_6208ef0f77            32574            68
# 9  content_c27558df2b0c  client_19581e27de             1240             3
#
#    content_age_days trend_direction
# 0               187            down
# 1               445            down
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule depends on manually chosen thresholds. ML can combine multiple signals and identify patterns across them that may be difficult to represent with a single if-statement. I will compare the ML approach against a transparent baseline rather than assuming ML is automatically better.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
